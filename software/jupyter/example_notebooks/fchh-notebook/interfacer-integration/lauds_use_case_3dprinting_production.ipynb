# %%
# Module imports and auto-reload setup
# %load_ext autoreload
# %aimport if_lib, if_utils, if_dpp, if_graphics, if_consts, if_gc1dpp
# %autoreload 1
import os
import json
import random

from if_utils import get_filename, show_data, save_traces

from if_lib import generate_random_challenge, read_HMAC, read_keypair, get_id_person, get_location_id, \
get_unit_id, get_resource_spec_id, get_resource, get_process, create_event, make_transfer, reduce_resource, set_user_location

from if_dpp import trace_query, check_traces, er_before, get_dpp

from if_graphics import vis_dpp, make_sankey, consol_trace

from if_gc1dpp import submit_dpp, create_sample_bike_dpp,create_sample_luffy_3d_object_dpp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Configuration and Endpoints

# %%
# Define constants - must match the setup notebook
USE_CASE = 'Lauds_Machine-3D-Printer'

# Zenflows API endpoint
ENDPOINT = 'https://proxy.dpp-staging.dyne.im/zenflows/api'

# DPP service endpoint
DPP_URL = 'https://proxy.dpp-staging.dyne.im/interfacer-dpp'

# All participants
USERS = ['designer1', 'designer2', 'service_prov1', 'service_prov2', 'manufacturer1', 'manufacturer2', 'customer1', 'customer2']

# %% [markdown]
# ## Load Setup Data from JSON Files

# %%
# Calculate file paths
USERS_FILE = get_filename('cred_users.json', ENDPOINT, USE_CASE)
LOCS_FILE = get_filename('loc_users.json', ENDPOINT, USE_CASE)
UNITS_FILE = get_filename('units_data.json', ENDPOINT, USE_CASE)
SPECS_FILE = get_filename('res_spec_data.json', ENDPOINT, USE_CASE)
DPP_FILE = get_filename('dpp_data.json', ENDPOINT, USE_CASE)
RES_FILE = get_filename('initial_resources.json', ENDPOINT, USE_CASE)
PROCESS_FILE = get_filename('process_data.json', ENDPOINT, USE_CASE)

# Load all data
print("Loading setup data...")

with open(USERS_FILE, 'r') as f:
    users_data = json.loads(f.read())
print(f"✓ Loaded {len(users_data)} users")

with open(LOCS_FILE, 'r') as f:
    locs_data = json.loads(f.read())
print(f"✓ Loaded {len(locs_data)} locations")

with open(UNITS_FILE, 'r') as f:
    units_data = json.loads(f.read())
print(f"✓ Loaded {len(units_data)} units")

with open(SPECS_FILE, 'r') as f:
    res_spec_data = json.loads(f.read())
print(f"✓ Loaded {len(res_spec_data)} resource specifications")

with open(PROCESS_FILE, 'r') as f:
    process_data = json.loads(f.read())
print(f"✓ Loaded {len(process_data)} processes")

with open(RES_FILE, 'r') as f:
    res_data = json.loads(f.read())
print(f"✓ Loaded {len(res_data)} initial resources")

# Initialize event sequence and DPP data
event_seq = []
dpp_data = {}

print("\n✓ All setup data loaded successfully!")
# Out:
# Loading setup data...
# ✓ Loaded 2 users
# ✓ Loaded 2 locations
# ✓ Loaded 5 units
# ✓ Loaded 5 resource specifications
# ✓ Loaded 1 processes
# ✓ Loaded 5 initial resources
#
# ✓ All setup data loaded successfully!

# %% [markdown]
# ## Verify Loaded Components
#
# Let's verify that all the bike components were successfully loaded from the setup notebook.

# %%
# Verify that all components are available
print("Checking for required components...")
required_components = ['3D-object-Luffy']

all_present = True
for component in required_components:
    if component in res_data:
        print(f"✓ {component}: {res_data[component]['id']}")
    else:
        print(f"✗ {component}: NOT FOUND")
        all_present = False

if all_present:
    print(f"\n✓ All components loaded successfully! Ready to create the bike.")
else:
    print(f"\n✗ Some components are missing. Please run the setup notebook first.")
# Out:
# Checking for required components...
# ✓ 3D-object-Luffy: 06E0HENR5WEJBR71GZGW5V9G04
#
# ✓ All components loaded successfully! Ready to create the bike.

# %% [markdown]
# ## Create GC1DPP Digital Product Passport (BEFORE Production)
#
# **This is the key innovation**: Create and submit the Digital Product Passport **BEFORE** producing the final bike.

# %%
# Create the GC1DPP data for the fancy 3D-object-Luffy (BEFORE producing it)
bike_dpp = create_sample_luffy_3d_object_dpp()

# Customize the DPP data with information about the components we've already created
bike_dpp['productOverview']['productName']['value'] = 'fancy 3D-object-Luffy'
bike_dpp['productOverview']['productDescription']['value'] = f"A unique 3D-object-Luffy"

# Add component information based on the resources we created
bike_dpp['components'] = [
    {
        "componentDescription": {"type": "string", "value": res_data['3D-object-Luffy']['name']},
        "componentGTIN": {"type": "string", "value": res_data['3D-object-Luffy']['res_ref_id']}
    },

]

# Update economic operator with actual user info
bike_dpp['economicOperator']['companyName']['value'] = users_data['A']['name']
bike_dpp['economicOperator']['addressLine1']['value'] = locs_data['A']['addr'].split(',')[0]
bike_dpp['economicOperator']['addressLine2']['value'] = ','.join(locs_data['A']['addr'].split(',')[1:])

print("✓ DPP data created (3D-object-Luffy)")
print(json.dumps(bike_dpp, indent=2))
# Out:
# ✓ DPP data created (3D-object-Luffy)
# {
#   "productOverview": {
#     "brandName": {
#       "type": "string",
#       "value": "Straw Hat Studios"
#     },
#     "productName": {
#       "type": "string",
#       "value": "fancy 3D-object-Luffy"
#     },
#     "productDescription": {
#       "type": "string",
#       "value": "A unique 3D-object-Luffy"
#     },
#     "countryOfOrigin": {
#       "type": "string",
#       "value": "Japan"
#     },
#     "color": {
#       "type": "string",
#       "value": "Multi-color"
#     },
#     "netWeight": {
#       "type": "number",
#       "value": 1.2,
#       "units": "kg"
#     },
#     "modelName": {
#       "type": "string",
#       "value": "LUFFY-3D-2025"
#     }
#   },
#   "reparability": {
#     "availabilityOfSpareParts": {
#       "type": "string",
#       "value": "Limited parts available through licensed distributor"
#     }
#   },
#   "environmentalImpact": {
#     "co2eEmissionsPerUnit": {
#       "type": "number",
#       "value": 8,
#       "units": "kg"
#     },
#     "minimumContentOfMaterialWithSustainabilityCertification": {
#       "type": "number",
#       "value": 40,
#       "units": "%"
#     }
#   },
#   "components": [
#     {
#       "componentDescription": {
#         "type": "string",
#         "value": "3D-object-Luffy"
#       },
#       "componentGTIN": {
#         "type": "string",
#         "value": "3D-object-Luffy-5595"
#       }
#     }
#   ],
#   "economicOperator": {
#     "companyName": {
#       "type": "string",
#       "value": "User A"
#     },
#     "addressLine1": {
#       "type": "string",
#       "value": "Oosterpark 9"
#     },
#     "addressLine2": {
#       "type": "string",
#       "value": " 1091 AC Amsterdam"
#     }
#   },
#   "recyclability": {
#     "materialComposition": {
#       "type": "string",
#       "value": "Resin: 70%, Acrylic paint: 10%, Other materials: 20%"
#     }
#   }
# }

# %% [markdown]
# ## Submit DPP to GC1DPP Service

# %%
# Submit the DPP to the DPP service BEFORE creating the bike
try:
    dpp_ulid = submit_dpp(
        bike_dpp,
        users_data['A']['eddsa_public_key'],
        users_data['A']['keyring']['eddsa'],
        DPP_URL
    )
    
    print(f"✓ DPP submitted successfully with ULID: {dpp_ulid}")
    
    # Store the DPP ULID - we'll use it when creating the bike
    bike_metadata = {
        'dpp': dpp_ulid
    }
    
    print(f"✓ DPP ULID ready to be added to bike metadata: {dpp_ulid}")
    
except Exception as e:
    print(f"✗ Error submitting DPP: {e}")
    print("Note: Make sure the DPP service is running at", DPP_URL)
    dpp_ulid = None
    bike_metadata = {}
# Out:
# Submitting DPP to https://proxy.dpp-staging.dyne.im/interfacer-dpp/dpp
# Public key: b3XYnrMAPYre61K2jH6g...
# Signature: HbhPZd0lmA71A1XloM/eULxllNnKWR+yNJYCMy7T...
# DPP submitted with ULID: 01KG4BP81JNDK92AKTD909JWBP
# ✓ DPP submitted successfully with ULID: 01KG4BP81JNDK92AKTD909JWBP
# ✓ DPP ULID ready to be added to bike metadata: 01KG4BP81JNDK92AKTD909JWBP

# %% [markdown]
# ## Produce the 3D-object-Luffy (with DPP Metadata)
#
# Now we produce the final 3D-object-Luffy, embedding the DPP ULID in its metadata at creation time.

# %%
# Debug: Check what we're about to send
print("3D-object-Luffy_metadata content:")
print(bike_metadata)
print("\nType:", type(bike_metadata))
if bike_metadata:
    print("dppUlid:", bike_metadata.get('dpp'))
# Out:
# 3D-object-Luffy_metadata content:
# {'dpp': '01KG4BP81JNDK92AKTD909JWBP'}
#
# Type: <class 'dict'>
# dppUlid: 01KG4BP81JNDK92AKTD909JWBP

# %%
# # Produce the fancy collaborative bike with all consumption/cite events
# cur_res = action = event_note = amount = cur_pros = None
# cur_pros = process_data['Create_3D_object_Luffy']

# action = 'consume'
# event_note = 'consume filament for 3D-object-Luffy'
# amount = 50  # example: 50 grams, adjust as needed
# cur_pros = process_data['Create_3D_object_Luffy']

# cur_res = res_data['Filament']  # pre-existing

# event_id, ts = create_event(
#     provider=users_data['A'],
#     action='consume',                   # action on existing resource
#     note='consume filament for 3D-object-Luffy',
#     amount=50,
#     process=process_data['Create_3D_object_Luffy'],
#     res_spec_data=res_spec_data,
#     existing_res=cur_res,              # use existing_res, NOT new_res
#     endpoint=ENDPOINT
# )
# event_seq.append({'ts': ts, 'event_id': event_id, 'action': action, 'res_name': cur_res['name'], 'res': cur_res['id']})

# # Define event consume for electrical energy
# cur_res = action = event_note = amount = cur_pros = None
# action = 'consume'
# event_note = 'consume electrical energy for 3D-object-Luffy'
# amount = 500  # example: 500 Wh, adjust as needed
# cur_pros = process_data['Create_3D_object_Luffy']

# cur_res = res_data['Electrical-Energy']

# event_id, ts = create_event(users_data['A'], action, event_note, amount=amount, process=cur_pros,
#                  res_spec_data=res_spec_data, existing_res=cur_res, endpoint=ENDPOINT)

# event_seq.append({'ts': ts, 'event_id': event_id, 'action': action, 'res_name': cur_res['name'], 'res': cur_res['id']})

# # con# Define event cite for 3D gcode file
# cur_res = action = event_note = amount = cur_pros = None
# action = 'cite'
# event_note = 'cite 3D-gcode-file-Luffy'
# amount = 1
# cur_pros = process_data['Create_3D_object_Luffy']

# cur_res = res_data['3D-gcode-file-Luffy']

# event_id, ts = create_event(users_data['A'], action, event_note, amount=amount, process=cur_pros,
#                  res_spec_data=res_spec_data, existing_res=cur_res, endpoint=ENDPOINT)

# event_seq.append({'ts': ts, 'event_id': event_id, 'action': action, 'res_name': cur_res['name'], 'res': cur_res['id']})

# # Define event produce for 3D object “Luffy”
# cur_res = action = event_note = amount = cur_pros = None
# action = 'produce'
# event_note = 'produce 3D-object-Luffy'
# amount = 1
# cur_pros = process_data['Create_3D_object_Luffy']

# res_data['3D-object-Luffy'] = {
#     "res_ref_id": f'3D-object-Luffy-{random.randint(0, 10000)}',
#     "name": '3D-object-Luffy',
#     "spec_id": res_spec_data['3D-object-Luffy']['id']
# }

# print(res_data['3D-object-Luffy'])
# cur_res = res_data['3D-object-Luffy']

# event_id, ts = create_event(users_data['A'], action, event_note, amount=amount, process=cur_pros,
#                  res_spec_data=res_spec_data, new_res=cur_res, endpoint=ENDPOINT)

# event_seq.append({'ts': ts, 'event_id': event_id, 'action': action, 'res_name': cur_res['name'], 'res': cur_res['id']})
# event_seq.append({'ts': ts, 'process_id':cur_pros['id'], 'name' : cur_pros['name']})
# print(f"\n✓ Bike created with ID: {cur_res['id']}")
# if bike_metadata:
#     print(f"✓ Bike metadata includes DPP ULID: {bike_metadata.get('dpp', 'N/A')}")
# Out:
# {'res_ref_id': '3D-object-Luffy-8188', 'name': '3D-object-Luffy', 'spec_id': '06DZMBJ9C45H8HMYYPBJ8KY880'}
#
# ✓ Bike created with ID: 06DZMBRKBHMMKRRNRGH3FBZVF8
# ✓ Bike metadata includes DPP ULID: None

# %% [markdown]
# ## Save DPP Data for Future Reference

# %%
# Save the DPP data to file for future reference
if dpp_ulid:
    res_data['3D-object-Luffy']['dpp_ulid'] = dpp_ulid
    dpp_data['3D-object-Luffy'] = {
        'ulid': dpp_ulid,
        'resource_id': res_data['3D-object-Luffy']['id'],
        'resource_ref_id': res_data['3D-object-Luffy']['res_ref_id'],
        'dpp': bike_dpp
    }
    
    # Save DPP data to file
    if os.path.isfile(DPP_FILE):
        with open(DPP_FILE, 'r') as f:
            existing_dpp_data = json.loads(f.read())
    else:
        existing_dpp_data = {}
    
    existing_dpp_data.update(dpp_data)
    
    with open(DPP_FILE, 'w') as f:
        json.dump(existing_dpp_data, f, indent=2)
    
    print(f"✓ DPP data saved to {DPP_FILE}")
else:
    print("⚠ No DPP ULID available to save")
# Out:
# ✓ DPP data saved to use_cases/Lauds_Machine-3D-Printer/proxy.dpp-staging.dyne.im%2Fzenflows%2Fapi/dpp_data.json

# %% [markdown]
# ## Display Summary Data

# %%
# Display summary of created resources and DPP
show_data(users_data, locs_data, res_data, units_data, res_spec_data, process_data, event_seq)
# Out:
# Users
# {
#   "A": {
#     "userChallenges": {
#       "whereParentsMet": "London",
#       "nameFirstPet": "Fuffy",
#       "nameFirstTeacher": "Jim",
#       "whereHomeTown": "Paris",
#       "nameMotherMaid": "Wright"
#     },
#     "name": "User A",
#     "username": "userA_username",
#     "email": "userA@example.org",
#     "note": "me.userA.org",
#     "seedServerSideShard.HMAC": "IqaW9oqMFSNgrjXsU2U/EwT4FugadCm8ZVFqkcT4spc=",
#     "seed": "solution garage know special trap wheel timber raven measure miracle achieve horn",
#     "eddsa_public_key": "b3XYnrMAPYre61K2jH6gq3A4G6xZrKYfuZ9kwihs55S",
#     "keyring": {
#       "eddsa": "DCqKRyK14C3Jmk4ifpGgMQFcv8nznouynSYXA8RMRieC"
#     },
#     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#     "location_id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#   },
#   "B": {
#     "userChallenges": {
#       "whereParentsMet": "Amsterdam",
#       "nameFirstPet": "Toby",
#       "nameFirstTeacher": "Juliet",
#       "whereHomeTown": "Rome",
#       "nameMotherMaid": "Banks"
#     },
#     "name": "User B",
#     "username": "userB",
#     "email": "userB@example.org",
#     "note": "me.userB.org",
#     "seedServerSideShard.HMAC": "kcpCZar+hOtFyeM05zzuVg5MNLDSfCHfjYd3NJTnImQ=",
#     "seed": "laundry arrest purpose enlist portion tourist zero robot loyal afraid liquid address",
#     "eddsa_public_key": "3woy151iWdPAeLn3BucSXNNKL1iW1sdYgxvKFmNTPFQf",
#     "keyring": {
#       "eddsa": "A1cN8gtRs4iH81Mkczu6KqnaMAry2bgtjje7DHc5KkXP"
#     },
#     "id": "06DY599HDJMGJT31C3HXR6D0S8",
#     "location_id": "06E0HEM8RYW19F5DXQV606SZDM"
#   }
# }
# Locations
# {
#   "A": {
#     "name": "OLVG",
#     "lat": 52.35871773455108,
#     "long": 4.916762398221842,
#     "addr": "Oosterpark 9, 1091 AC Amsterdam",
#     "note": "location.user1.org",
#     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#     "user_id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#   },
#   "B": {
#     "name": "CleanLease",
#     "lat": 51.47240440868687,
#     "long": 5.412460440524406,
#     "addr": "De schakel 30, 5651 Eindhoven",
#     "note": "location.user2.org",
#     "id": "06E0HEM8RYW19F5DXQV606SZDM",
#     "user_id": "06DY599HDJMGJT31C3HXR6D0S8"
#   }
# }
# Resources
# {
#   "Machine-3D-Printer": {
#     "res_ref_id": "Machine-3D-Printer-4745",
#     "name": "Machine-3D-Printer",
#     "spec_id": "06E0HEMVB6WXDGCA6J8QZMG3XG",
#     "id": "06E0HEN6HWB1NV26JQ00KXVN74"
#   },
#   "Filament": {
#     "res_ref_id": "Filament-2103",
#     "name": "Filament",
#     "spec_id": "06E0HEMXT5EQ3E9A0GE1KY5KNW",
#     "id": "06E0HEN9QC49441DD7QNWSWKH8"
#   },
#   "Electrical-Energy": {
#     "res_ref_id": "Electrical-Energy-4467",
#     "name": "Electrical-Energy",
#     "spec_id": "06E0HEN0HSAHNR4DWXDQS2KCV0",
#     "id": "06E0HENBRZWNFPT7GPWY892ZB8"
#   },
#   "3D-gcode-file-Luffy": {
#     "res_ref_id": "3D-gcode-file-Luffy-4598",
#     "name": "3D-gcode-file-Luffy",
#     "spec_id": "06E0HEN4HR98SD89N1PWGPAHJ8",
#     "id": "06E0HENE47K7BVKH5XPGZW4QCW"
#   },
#   "3D-object-Luffy": {
#     "res_ref_id": "3D-object-Luffy-5595",
#     "name": "3D-object-Luffy",
#     "spec_id": "06E0HEN30JT66WW95TAZZDYNG0",
#     "id": "06E0HENR5WEJBR71GZGW5V9G04",
#     "dpp_ulid": "01KG4BP81JNDK92AKTD909JWBP"
#   }
# }
# Units
# {
#   "piece": {
#     "label": "u_piece",
#     "symbol": "om2:one",
#     "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#   },
#   "mass": {
#     "label": "kg",
#     "symbol": "om2:kilogram",
#     "id": "06E0HEMG54NJ6C3N54Z9FNA848"
#   },
#   "volume": {
#     "label": "lt",
#     "symbol": "om2:litre",
#     "id": "06E0HEMJEZXH91V9K5P32KZB6M"
#   },
#   "time": {
#     "label": "h",
#     "symbol": "om2:hour",
#     "id": "06E0HEMMEV822K7S76H3A4CAPG"
#   },
#   "energy": {
#     "label": "Wh",
#     "symbol": "om2:wattHour",
#     "id": "06E0HEMPXGECEQSRQDD9M1XHER"
#   }
# }
# Resource Specifications
# {
#   "Machine-3D-Printer": {
#     "note": "Specification for the 3D printer used by the operator",
#     "classification": "https://www.wikidata.org/wiki/Q2095",
#     "defaultUnit": "06E0HEMDRGE0944KEG0W0JNSH8",
#     "id": "06E0HEMVB6WXDGCA6J8QZMG3XG"
#   },
#   "Filament": {
#     "note": "Specification for 3D printing filament material",
#     "classification": "https://www.wikidata.org/wiki/Q11782",
#     "defaultUnit": "06E0HEMG54NJ6C3N54Z9FNA848",
#     "id": "06E0HEMXT5EQ3E9A0GE1KY5KNW"
#   },
#   "Electrical-Energy": {
#     "note": "Specification for electrical energy consumed during 3D printing",
#     "classification": "https://www.wikidata.org/wiki/Q6837",
#     "defaultUnit": "06E0HEMPXGECEQSRQDD9M1XHER",
#     "id": "06E0HEN0HSAHNR4DWXDQS2KCV0"
#   },
#   "3D-object-Luffy": {
#     "note": "Specification for the 3D printed object named Luffy",
#     "classification": "https://www.wikidata.org/wiki/Q1248784",
#     "defaultUnit": "06E0HEMDRGE0944KEG0W0JNSH8",
#     "id": "06E0HEN30JT66WW95TAZZDYNG0"
#   },
#   "3D-gcode-file-Luffy": {
#     "note": "Specification for the 3D printing G-code file for Luffy",
#     "classification": "https://www.wikidata.org/wiki/Q1073076",
#     "defaultUnit": "06E0HEMDRGE0944KEG0W0JNSH8",
#     "id": "06E0HEN4HR98SD89N1PWGPAHJ8"
#   }
# }
# Process Definitions
# {
#   "Create_3D_object_Luffy": {
#     "name": "Create_3D_object_Luffy",
#     "note": "3D printing process to create object 'Luffy' performed by User A",
#     "id": "06E0HEMRY7GH2V2TWQX93CQE84"
#   }
# }
# Event sequence
# []
# Proposal data
# {}
# Intent data
# {}
# Proposed Intent data
# {}
# Satisfaction data
# {}
# Process Groups data
# {}

# %% [markdown]
# ## Supply Chain Tracing and Visualization
#
# ### Backward Tracing: Find All Inputs

# %%
trace_me = res_data['3D-object-Luffy']['id']
print(f"Resource to be traced: {trace_me}")
tot_dpp = []
visited = set()
er_before(trace_me, users_data['A'], dpp_children=tot_dpp, depth=0, visited=visited, endpoint=ENDPOINT)

# Serializing json
json_object = json.dumps(tot_dpp, indent=2)

print(json_object)
print(f"\n✓ Traced {len(visited)} resources")
# Out:
# Resource to be traced: 06E0HENR5WEJBR71GZGW5V9G04
# [
#   {
#     "accountingQuantity": {
#       "hasNumericalValue": "1",
#       "hasUnit": {
#         "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#         "label": "u_piece",
#         "symbol": "om2:one"
#       }
#     },
#     "currentLocation": {
#       "alt": "0",
#       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#       "lat": "52.35871773455108",
#       "long": "4.916762398221842",
#       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#       "name": "OLVG",
#       "note": "location.user1.org"
#     },
#     "custodian": {
#       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#       "name": "User A",
#       "note": null,
#       "primaryLocation": {
#         "alt": "0",
#         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#         "lat": "52.35871773455108",
#         "long": "4.916762398221842",
#         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#         "name": "OLVG",
#         "note": "location.user1.org"
#       },
#       "type": "Person"
#     },
#     "id": "06E0HENR5WEJBR71GZGW5V9G04",
#     "metadata": null,
#     "name": "3D-object-Luffy",
#     "onhandQuantity": {
#       "hasNumericalValue": "1",
#       "hasUnit": {
#         "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#         "label": "u_piece",
#         "symbol": "om2:one"
#       }
#     },
#     "primaryAccountable": {
#       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#       "name": "User A",
#       "note": null,
#       "primaryLocation": {
#         "alt": "0",
#         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#         "lat": "52.35871773455108",
#         "long": "4.916762398221842",
#         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#         "name": "OLVG",
#         "note": "location.user1.org"
#       },
#       "type": "Person"
#     },
#     "trackingIdentifier": "3D-object-Luffy-5595",
#     "type": "EconomicResource",
#     "children": [
#       {
#         "action": {
#           "id": "produce",
#           "inputOutput": "output",
#           "label": "produce",
#           "onhandEffect": "increment",
#           "pairsWith": "notApplicable",
#           "resourceEffect": "increment"
#         },
#         "agreedIn": null,
#         "atLocation": null,
#         "effortQuantity": null,
#         "hasBeginning": null,
#         "hasEnd": null,
#         "hasPointInTime": "2026-01-29T07:49:39.734309Z",
#         "id": "06E0HENR5F94R1GQJRGXB8X2ZC",
#         "inputOf": null,
#         "note": "produce 3D-object-Luffy",
#         "outputOf": {
#           "basedOn": null,
#           "classifiedAs": null,
#           "deletable": false,
#           "finished": false,
#           "groupedIn": null,
#           "hasBeginning": "2026-01-29T07:49:32.042607Z",
#           "hasEnd": "2026-01-29T07:49:32.042607Z",
#           "id": "06E0HEMRY7GH2V2TWQX93CQE84",
#           "name": "Create_3D_object_Luffy",
#           "nestedIn": null,
#           "note": "3D printing process to create object 'Luffy' performed by User A",
#           "plannedWithin": null,
#           "type": "Process"
#         },
#         "provider": {
#           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#           "name": "User A",
#           "note": null,
#           "primaryLocation": {
#             "alt": "0",
#             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#             "lat": "52.35871773455108",
#             "long": "4.916762398221842",
#             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#             "name": "OLVG",
#             "note": "location.user1.org"
#           },
#           "type": "Person"
#         },
#         "realizationOf": null,
#         "receiver": {
#           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#           "name": "User A",
#           "note": null,
#           "primaryLocation": {
#             "alt": "0",
#             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#             "lat": "52.35871773455108",
#             "long": "4.916762398221842",
#             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#             "name": "OLVG",
#             "note": "location.user1.org"
#           },
#           "type": "Person"
#         },
#         "resourceClassifiedAs": null,
#         "resourceConformsTo": {
#           "defaultUnitOfEffort": null,
#           "defaultUnitOfResource": {
#             "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#             "label": "u_piece",
#             "symbol": "om2:one"
#           },
#           "id": "06E0HEN30JT66WW95TAZZDYNG0",
#           "name": "3D-object-Luffy",
#           "note": "Specification for the 3D printed object named Luffy",
#           "resourceClassifiedAs": [
#             "https://www.wikidata.org/wiki/Q1248784"
#           ]
#         },
#         "resourceInventoriedAs": {
#           "accountingQuantity": {
#             "hasNumericalValue": "1",
#             "hasUnit": {
#               "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#               "label": "u_piece",
#               "symbol": "om2:one"
#             }
#           },
#           "currentLocation": {
#             "alt": "0",
#             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#             "lat": "52.35871773455108",
#             "long": "4.916762398221842",
#             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#             "name": "OLVG",
#             "note": "location.user1.org"
#           },
#           "custodian": {
#             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#             "name": "User A",
#             "note": null,
#             "primaryLocation": {
#               "alt": "0",
#               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#               "lat": "52.35871773455108",
#               "long": "4.916762398221842",
#               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#               "name": "OLVG",
#               "note": "location.user1.org"
#             },
#             "type": "Person"
#           },
#           "id": "06E0HENR5WEJBR71GZGW5V9G04",
#           "metadata": null,
#           "name": "3D-object-Luffy",
#           "onhandQuantity": {
#             "hasNumericalValue": "1",
#             "hasUnit": {
#               "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#               "label": "u_piece",
#               "symbol": "om2:one"
#             }
#           },
#           "primaryAccountable": {
#             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#             "name": "User A",
#             "note": null,
#             "primaryLocation": {
#               "alt": "0",
#               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#               "lat": "52.35871773455108",
#               "long": "4.916762398221842",
#               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#               "name": "OLVG",
#               "note": "location.user1.org"
#             },
#             "type": "Person"
#           },
#           "trackingIdentifier": "3D-object-Luffy-5595",
#           "type": "EconomicResource"
#         },
#         "resourceQuantity": {
#           "hasNumericalValue": "1",
#           "hasUnit": {
#             "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#             "label": "u_piece",
#             "symbol": "om2:one"
#           }
#         },
#         "toLocation": {
#           "alt": "0",
#           "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#           "lat": "52.35871773455108",
#           "long": "4.916762398221842",
#           "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#           "name": "OLVG",
#           "note": "location.user1.org"
#         },
#         "toResourceInventoriedAs": null,
#         "triggeredBy": null,
#         "type": "EconomicEvent",
#         "name": "produce",
#         "children": [
#           {
#             "basedOn": null,
#             "classifiedAs": null,
#             "deletable": false,
#             "finished": false,
#             "groupedIn": null,
#             "hasBeginning": "2026-01-29T07:49:32.042607Z",
#             "hasEnd": "2026-01-29T07:49:32.042607Z",
#             "id": "06E0HEMRY7GH2V2TWQX93CQE84",
#             "name": "Create_3D_object_Luffy",
#             "nestedIn": null,
#             "note": "3D printing process to create object 'Luffy' performed by User A",
#             "plannedWithin": null,
#             "type": "Process",
#             "children": [
#               {
#                 "action": {
#                   "id": "cite",
#                   "inputOutput": "input",
#                   "label": "cite",
#                   "onhandEffect": "noEffect",
#                   "pairsWith": "notApplicable",
#                   "resourceEffect": "noEffect"
#                 },
#                 "agreedIn": null,
#                 "atLocation": null,
#                 "effortQuantity": null,
#                 "hasBeginning": null,
#                 "hasEnd": null,
#                 "hasPointInTime": "2026-01-29T07:49:39.117151Z",
#                 "id": "06E0HENMKG1JBBC73YGP9Z9Q7C",
#                 "inputOf": {
#                   "basedOn": null,
#                   "classifiedAs": null,
#                   "deletable": false,
#                   "finished": false,
#                   "groupedIn": null,
#                   "hasBeginning": "2026-01-29T07:49:32.042607Z",
#                   "hasEnd": "2026-01-29T07:49:32.042607Z",
#                   "id": "06E0HEMRY7GH2V2TWQX93CQE84",
#                   "name": "Create_3D_object_Luffy",
#                   "nestedIn": null,
#                   "note": "3D printing process to create object 'Luffy' performed by User A",
#                   "plannedWithin": null,
#                   "type": "Process"
#                 },
#                 "note": "cite 3D-gcode-file-Luffy",
#                 "outputOf": null,
#                 "provider": {
#                   "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                   "name": "User A",
#                   "note": null,
#                   "primaryLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "type": "Person"
#                 },
#                 "realizationOf": null,
#                 "receiver": {
#                   "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                   "name": "User A",
#                   "note": null,
#                   "primaryLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "type": "Person"
#                 },
#                 "resourceClassifiedAs": null,
#                 "resourceConformsTo": null,
#                 "resourceInventoriedAs": {
#                   "accountingQuantity": {
#                     "hasNumericalValue": "1",
#                     "hasUnit": {
#                       "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                       "label": "u_piece",
#                       "symbol": "om2:one"
#                     }
#                   },
#                   "currentLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "custodian": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                     "name": "User A",
#                     "note": null,
#                     "primaryLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "type": "Person"
#                   },
#                   "id": "06E0HENE47K7BVKH5XPGZW4QCW",
#                   "metadata": null,
#                   "name": "3D-gcode-file-Luffy",
#                   "onhandQuantity": {
#                     "hasNumericalValue": "1",
#                     "hasUnit": {
#                       "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                       "label": "u_piece",
#                       "symbol": "om2:one"
#                     }
#                   },
#                   "primaryAccountable": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                     "name": "User A",
#                     "note": null,
#                     "primaryLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "type": "Person"
#                   },
#                   "trackingIdentifier": "3D-gcode-file-Luffy-4598",
#                   "type": "EconomicResource"
#                 },
#                 "resourceQuantity": {
#                   "hasNumericalValue": "1",
#                   "hasUnit": {
#                     "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                     "label": "u_piece",
#                     "symbol": "om2:one"
#                   }
#                 },
#                 "toLocation": null,
#                 "toResourceInventoriedAs": null,
#                 "triggeredBy": null,
#                 "type": "EconomicEvent",
#                 "name": "cite",
#                 "children": [
#                   {
#                     "accountingQuantity": {
#                       "hasNumericalValue": "1",
#                       "hasUnit": {
#                         "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                         "label": "u_piece",
#                         "symbol": "om2:one"
#                       }
#                     },
#                     "currentLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "custodian": {
#                       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                       "name": "User A",
#                       "note": null,
#                       "primaryLocation": {
#                         "alt": "0",
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                         "lat": "52.35871773455108",
#                         "long": "4.916762398221842",
#                         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                         "name": "OLVG",
#                         "note": "location.user1.org"
#                       },
#                       "type": "Person"
#                     },
#                     "id": "06E0HENE47K7BVKH5XPGZW4QCW",
#                     "metadata": null,
#                     "name": "3D-gcode-file-Luffy",
#                     "onhandQuantity": {
#                       "hasNumericalValue": "1",
#                       "hasUnit": {
#                         "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                         "label": "u_piece",
#                         "symbol": "om2:one"
#                       }
#                     },
#                     "primaryAccountable": {
#                       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                       "name": "User A",
#                       "note": null,
#                       "primaryLocation": {
#                         "alt": "0",
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                         "lat": "52.35871773455108",
#                         "long": "4.916762398221842",
#                         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                         "name": "OLVG",
#                         "note": "location.user1.org"
#                       },
#                       "type": "Person"
#                     },
#                     "trackingIdentifier": "3D-gcode-file-Luffy-4598",
#                     "type": "EconomicResource",
#                     "children": [
#                       {
#                         "action": {
#                           "id": "raise",
#                           "inputOutput": "notApplicable",
#                           "label": "raise",
#                           "onhandEffect": "increment",
#                           "pairsWith": "notApplicable",
#                           "resourceEffect": "increment"
#                         },
#                         "agreedIn": null,
#                         "atLocation": null,
#                         "effortQuantity": null,
#                         "hasBeginning": null,
#                         "hasEnd": null,
#                         "hasPointInTime": "2026-01-29T07:49:37.371061Z",
#                         "id": "06E0HENE3V22AHWYXSMRQP4944",
#                         "inputOf": null,
#                         "note": "create resource",
#                         "outputOf": null,
#                         "provider": {
#                           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                           "name": "User A",
#                           "note": null,
#                           "primaryLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "type": "Person"
#                         },
#                         "realizationOf": null,
#                         "receiver": {
#                           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                           "name": "User A",
#                           "note": null,
#                           "primaryLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "type": "Person"
#                         },
#                         "resourceClassifiedAs": null,
#                         "resourceConformsTo": {
#                           "defaultUnitOfEffort": null,
#                           "defaultUnitOfResource": {
#                             "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                             "label": "u_piece",
#                             "symbol": "om2:one"
#                           },
#                           "id": "06E0HEN4HR98SD89N1PWGPAHJ8",
#                           "name": "3D-gcode-file-Luffy",
#                           "note": "Specification for the 3D printing G-code file for Luffy",
#                           "resourceClassifiedAs": [
#                             "https://www.wikidata.org/wiki/Q1073076"
#                           ]
#                         },
#                         "resourceInventoriedAs": {
#                           "accountingQuantity": {
#                             "hasNumericalValue": "1",
#                             "hasUnit": {
#                               "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                               "label": "u_piece",
#                               "symbol": "om2:one"
#                             }
#                           },
#                           "currentLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "custodian": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                             "name": "User A",
#                             "note": null,
#                             "primaryLocation": {
#                               "alt": "0",
#                               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                               "lat": "52.35871773455108",
#                               "long": "4.916762398221842",
#                               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                               "name": "OLVG",
#                               "note": "location.user1.org"
#                             },
#                             "type": "Person"
#                           },
#                           "id": "06E0HENE47K7BVKH5XPGZW4QCW",
#                           "metadata": null,
#                           "name": "3D-gcode-file-Luffy",
#                           "onhandQuantity": {
#                             "hasNumericalValue": "1",
#                             "hasUnit": {
#                               "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                               "label": "u_piece",
#                               "symbol": "om2:one"
#                             }
#                           },
#                           "primaryAccountable": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                             "name": "User A",
#                             "note": null,
#                             "primaryLocation": {
#                               "alt": "0",
#                               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                               "lat": "52.35871773455108",
#                               "long": "4.916762398221842",
#                               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                               "name": "OLVG",
#                               "note": "location.user1.org"
#                             },
#                             "type": "Person"
#                           },
#                           "trackingIdentifier": "3D-gcode-file-Luffy-4598",
#                           "type": "EconomicResource"
#                         },
#                         "resourceQuantity": {
#                           "hasNumericalValue": "1",
#                           "hasUnit": {
#                             "id": "06E0HEMDRGE0944KEG0W0JNSH8",
#                             "label": "u_piece",
#                             "symbol": "om2:one"
#                           }
#                         },
#                         "toLocation": {
#                           "alt": "0",
#                           "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                           "lat": "52.35871773455108",
#                           "long": "4.916762398221842",
#                           "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                           "name": "OLVG",
#                           "note": "location.user1.org"
#                         },
#                         "toResourceInventoriedAs": null,
#                         "triggeredBy": null,
#                         "type": "EconomicEvent",
#                         "name": "raise",
#                         "children": []
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "action": {
#                   "id": "consume",
#                   "inputOutput": "input",
#                   "label": "consume",
#                   "onhandEffect": "decrement",
#                   "pairsWith": "notApplicable",
#                   "resourceEffect": "decrement"
#                 },
#                 "agreedIn": null,
#                 "atLocation": null,
#                 "effortQuantity": null,
#                 "hasBeginning": null,
#                 "hasEnd": null,
#                 "hasPointInTime": "2026-01-29T07:49:38.607765Z",
#                 "id": "06E0HENJF7HGWV14D1S37PVASG",
#                 "inputOf": {
#                   "basedOn": null,
#                   "classifiedAs": null,
#                   "deletable": false,
#                   "finished": false,
#                   "groupedIn": null,
#                   "hasBeginning": "2026-01-29T07:49:32.042607Z",
#                   "hasEnd": "2026-01-29T07:49:32.042607Z",
#                   "id": "06E0HEMRY7GH2V2TWQX93CQE84",
#                   "name": "Create_3D_object_Luffy",
#                   "nestedIn": null,
#                   "note": "3D printing process to create object 'Luffy' performed by User A",
#                   "plannedWithin": null,
#                   "type": "Process"
#                 },
#                 "note": "consume electrical energy for 3D-object-Luffy",
#                 "outputOf": null,
#                 "provider": {
#                   "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                   "name": "User A",
#                   "note": null,
#                   "primaryLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "type": "Person"
#                 },
#                 "realizationOf": null,
#                 "receiver": {
#                   "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                   "name": "User A",
#                   "note": null,
#                   "primaryLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "type": "Person"
#                 },
#                 "resourceClassifiedAs": null,
#                 "resourceConformsTo": null,
#                 "resourceInventoriedAs": {
#                   "accountingQuantity": {
#                     "hasNumericalValue": "500",
#                     "hasUnit": {
#                       "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                       "label": "Wh",
#                       "symbol": "om2:wattHour"
#                     }
#                   },
#                   "currentLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "custodian": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                     "name": "User A",
#                     "note": null,
#                     "primaryLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "type": "Person"
#                   },
#                   "id": "06E0HENBRZWNFPT7GPWY892ZB8",
#                   "metadata": null,
#                   "name": "Electrical-Energy",
#                   "onhandQuantity": {
#                     "hasNumericalValue": "500",
#                     "hasUnit": {
#                       "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                       "label": "Wh",
#                       "symbol": "om2:wattHour"
#                     }
#                   },
#                   "primaryAccountable": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                     "name": "User A",
#                     "note": null,
#                     "primaryLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "type": "Person"
#                   },
#                   "trackingIdentifier": "Electrical-Energy-4467",
#                   "type": "EconomicResource"
#                 },
#                 "resourceQuantity": {
#                   "hasNumericalValue": "500",
#                   "hasUnit": {
#                     "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                     "label": "Wh",
#                     "symbol": "om2:wattHour"
#                   }
#                 },
#                 "toLocation": null,
#                 "toResourceInventoriedAs": null,
#                 "triggeredBy": null,
#                 "type": "EconomicEvent",
#                 "name": "consume",
#                 "children": [
#                   {
#                     "accountingQuantity": {
#                       "hasNumericalValue": "500",
#                       "hasUnit": {
#                         "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                         "label": "Wh",
#                         "symbol": "om2:wattHour"
#                       }
#                     },
#                     "currentLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "custodian": {
#                       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                       "name": "User A",
#                       "note": null,
#                       "primaryLocation": {
#                         "alt": "0",
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                         "lat": "52.35871773455108",
#                         "long": "4.916762398221842",
#                         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                         "name": "OLVG",
#                         "note": "location.user1.org"
#                       },
#                       "type": "Person"
#                     },
#                     "id": "06E0HENBRZWNFPT7GPWY892ZB8",
#                     "metadata": null,
#                     "name": "Electrical-Energy",
#                     "onhandQuantity": {
#                       "hasNumericalValue": "500",
#                       "hasUnit": {
#                         "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                         "label": "Wh",
#                         "symbol": "om2:wattHour"
#                       }
#                     },
#                     "primaryAccountable": {
#                       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                       "name": "User A",
#                       "note": null,
#                       "primaryLocation": {
#                         "alt": "0",
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                         "lat": "52.35871773455108",
#                         "long": "4.916762398221842",
#                         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                         "name": "OLVG",
#                         "note": "location.user1.org"
#                       },
#                       "type": "Person"
#                     },
#                     "trackingIdentifier": "Electrical-Energy-4467",
#                     "type": "EconomicResource",
#                     "children": [
#                       {
#                         "action": {
#                           "id": "raise",
#                           "inputOutput": "notApplicable",
#                           "label": "raise",
#                           "onhandEffect": "increment",
#                           "pairsWith": "notApplicable",
#                           "resourceEffect": "increment"
#                         },
#                         "agreedIn": null,
#                         "atLocation": null,
#                         "effortQuantity": null,
#                         "hasBeginning": null,
#                         "hasEnd": null,
#                         "hasPointInTime": "2026-01-29T07:49:36.854033Z",
#                         "id": "06E0HENBRC3M2CPY187PHCM7W4",
#                         "inputOf": null,
#                         "note": "create resource",
#                         "outputOf": null,
#                         "provider": {
#                           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                           "name": "User A",
#                           "note": null,
#                           "primaryLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "type": "Person"
#                         },
#                         "realizationOf": null,
#                         "receiver": {
#                           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                           "name": "User A",
#                           "note": null,
#                           "primaryLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "type": "Person"
#                         },
#                         "resourceClassifiedAs": null,
#                         "resourceConformsTo": {
#                           "defaultUnitOfEffort": null,
#                           "defaultUnitOfResource": {
#                             "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                             "label": "Wh",
#                             "symbol": "om2:wattHour"
#                           },
#                           "id": "06E0HEN0HSAHNR4DWXDQS2KCV0",
#                           "name": "Electrical-Energy",
#                           "note": "Specification for electrical energy consumed during 3D printing",
#                           "resourceClassifiedAs": [
#                             "https://www.wikidata.org/wiki/Q6837"
#                           ]
#                         },
#                         "resourceInventoriedAs": {
#                           "accountingQuantity": {
#                             "hasNumericalValue": "500",
#                             "hasUnit": {
#                               "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                               "label": "Wh",
#                               "symbol": "om2:wattHour"
#                             }
#                           },
#                           "currentLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "custodian": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                             "name": "User A",
#                             "note": null,
#                             "primaryLocation": {
#                               "alt": "0",
#                               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                               "lat": "52.35871773455108",
#                               "long": "4.916762398221842",
#                               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                               "name": "OLVG",
#                               "note": "location.user1.org"
#                             },
#                             "type": "Person"
#                           },
#                           "id": "06E0HENBRZWNFPT7GPWY892ZB8",
#                           "metadata": null,
#                           "name": "Electrical-Energy",
#                           "onhandQuantity": {
#                             "hasNumericalValue": "500",
#                             "hasUnit": {
#                               "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                               "label": "Wh",
#                               "symbol": "om2:wattHour"
#                             }
#                           },
#                           "primaryAccountable": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                             "name": "User A",
#                             "note": null,
#                             "primaryLocation": {
#                               "alt": "0",
#                               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                               "lat": "52.35871773455108",
#                               "long": "4.916762398221842",
#                               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                               "name": "OLVG",
#                               "note": "location.user1.org"
#                             },
#                             "type": "Person"
#                           },
#                           "trackingIdentifier": "Electrical-Energy-4467",
#                           "type": "EconomicResource"
#                         },
#                         "resourceQuantity": {
#                           "hasNumericalValue": "1000",
#                           "hasUnit": {
#                             "id": "06E0HEMPXGECEQSRQDD9M1XHER",
#                             "label": "Wh",
#                             "symbol": "om2:wattHour"
#                           }
#                         },
#                         "toLocation": {
#                           "alt": "0",
#                           "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                           "lat": "52.35871773455108",
#                           "long": "4.916762398221842",
#                           "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                           "name": "OLVG",
#                           "note": "location.user1.org"
#                         },
#                         "toResourceInventoriedAs": null,
#                         "triggeredBy": null,
#                         "type": "EconomicEvent",
#                         "name": "raise",
#                         "children": []
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "action": {
#                   "id": "consume",
#                   "inputOutput": "input",
#                   "label": "consume",
#                   "onhandEffect": "decrement",
#                   "pairsWith": "notApplicable",
#                   "resourceEffect": "decrement"
#                 },
#                 "agreedIn": null,
#                 "atLocation": null,
#                 "effortQuantity": null,
#                 "hasBeginning": null,
#                 "hasEnd": null,
#                 "hasPointInTime": "2026-01-29T07:49:37.989064Z",
#                 "id": "06E0HENG3EYV0ENHPDQZ4BPTG8",
#                 "inputOf": {
#                   "basedOn": null,
#                   "classifiedAs": null,
#                   "deletable": false,
#                   "finished": false,
#                   "groupedIn": null,
#                   "hasBeginning": "2026-01-29T07:49:32.042607Z",
#                   "hasEnd": "2026-01-29T07:49:32.042607Z",
#                   "id": "06E0HEMRY7GH2V2TWQX93CQE84",
#                   "name": "Create_3D_object_Luffy",
#                   "nestedIn": null,
#                   "note": "3D printing process to create object 'Luffy' performed by User A",
#                   "plannedWithin": null,
#                   "type": "Process"
#                 },
#                 "note": "consume filament for 3D-object-Luffy",
#                 "outputOf": null,
#                 "provider": {
#                   "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                   "name": "User A",
#                   "note": null,
#                   "primaryLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "type": "Person"
#                 },
#                 "realizationOf": null,
#                 "receiver": {
#                   "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                   "name": "User A",
#                   "note": null,
#                   "primaryLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "type": "Person"
#                 },
#                 "resourceClassifiedAs": null,
#                 "resourceConformsTo": null,
#                 "resourceInventoriedAs": {
#                   "accountingQuantity": {
#                     "hasNumericalValue": "-49",
#                     "hasUnit": {
#                       "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                       "label": "kg",
#                       "symbol": "om2:kilogram"
#                     }
#                   },
#                   "currentLocation": {
#                     "alt": "0",
#                     "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                     "lat": "52.35871773455108",
#                     "long": "4.916762398221842",
#                     "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                     "name": "OLVG",
#                     "note": "location.user1.org"
#                   },
#                   "custodian": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                     "name": "User A",
#                     "note": null,
#                     "primaryLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "type": "Person"
#                   },
#                   "id": "06E0HEN9QC49441DD7QNWSWKH8",
#                   "metadata": null,
#                   "name": "Filament",
#                   "onhandQuantity": {
#                     "hasNumericalValue": "-49",
#                     "hasUnit": {
#                       "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                       "label": "kg",
#                       "symbol": "om2:kilogram"
#                     }
#                   },
#                   "primaryAccountable": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                     "name": "User A",
#                     "note": null,
#                     "primaryLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "type": "Person"
#                   },
#                   "trackingIdentifier": "Filament-2103",
#                   "type": "EconomicResource"
#                 },
#                 "resourceQuantity": {
#                   "hasNumericalValue": "50",
#                   "hasUnit": {
#                     "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                     "label": "kg",
#                     "symbol": "om2:kilogram"
#                   }
#                 },
#                 "toLocation": null,
#                 "toResourceInventoriedAs": null,
#                 "triggeredBy": null,
#                 "type": "EconomicEvent",
#                 "name": "consume",
#                 "children": [
#                   {
#                     "accountingQuantity": {
#                       "hasNumericalValue": "-49",
#                       "hasUnit": {
#                         "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                         "label": "kg",
#                         "symbol": "om2:kilogram"
#                       }
#                     },
#                     "currentLocation": {
#                       "alt": "0",
#                       "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                       "lat": "52.35871773455108",
#                       "long": "4.916762398221842",
#                       "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                       "name": "OLVG",
#                       "note": "location.user1.org"
#                     },
#                     "custodian": {
#                       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                       "name": "User A",
#                       "note": null,
#                       "primaryLocation": {
#                         "alt": "0",
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                         "lat": "52.35871773455108",
#                         "long": "4.916762398221842",
#                         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                         "name": "OLVG",
#                         "note": "location.user1.org"
#                       },
#                       "type": "Person"
#                     },
#                     "id": "06E0HEN9QC49441DD7QNWSWKH8",
#                     "metadata": null,
#                     "name": "Filament",
#                     "onhandQuantity": {
#                       "hasNumericalValue": "-49",
#                       "hasUnit": {
#                         "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                         "label": "kg",
#                         "symbol": "om2:kilogram"
#                       }
#                     },
#                     "primaryAccountable": {
#                       "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                       "name": "User A",
#                       "note": null,
#                       "primaryLocation": {
#                         "alt": "0",
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                         "lat": "52.35871773455108",
#                         "long": "4.916762398221842",
#                         "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                         "name": "OLVG",
#                         "note": "location.user1.org"
#                       },
#                       "type": "Person"
#                     },
#                     "trackingIdentifier": "Filament-2103",
#                     "type": "EconomicResource",
#                     "children": [
#                       {
#                         "action": {
#                           "id": "raise",
#                           "inputOutput": "notApplicable",
#                           "label": "raise",
#                           "onhandEffect": "increment",
#                           "pairsWith": "notApplicable",
#                           "resourceEffect": "increment"
#                         },
#                         "agreedIn": null,
#                         "atLocation": null,
#                         "effortQuantity": null,
#                         "hasBeginning": null,
#                         "hasEnd": null,
#                         "hasPointInTime": "2026-01-29T07:49:36.136282Z",
#                         "id": "06E0HEN9Q7XH0YRTNKRC1XBW94",
#                         "inputOf": null,
#                         "note": "create resource",
#                         "outputOf": null,
#                         "provider": {
#                           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                           "name": "User A",
#                           "note": null,
#                           "primaryLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "type": "Person"
#                         },
#                         "realizationOf": null,
#                         "receiver": {
#                           "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                           "name": "User A",
#                           "note": null,
#                           "primaryLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "type": "Person"
#                         },
#                         "resourceClassifiedAs": null,
#                         "resourceConformsTo": {
#                           "defaultUnitOfEffort": null,
#                           "defaultUnitOfResource": {
#                             "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                             "label": "kg",
#                             "symbol": "om2:kilogram"
#                           },
#                           "id": "06E0HEMXT5EQ3E9A0GE1KY5KNW",
#                           "name": "Filament",
#                           "note": "Specification for 3D printing filament material",
#                           "resourceClassifiedAs": [
#                             "https://www.wikidata.org/wiki/Q11782"
#                           ]
#                         },
#                         "resourceInventoriedAs": {
#                           "accountingQuantity": {
#                             "hasNumericalValue": "-49",
#                             "hasUnit": {
#                               "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                               "label": "kg",
#                               "symbol": "om2:kilogram"
#                             }
#                           },
#                           "currentLocation": {
#                             "alt": "0",
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                             "lat": "52.35871773455108",
#                             "long": "4.916762398221842",
#                             "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                             "name": "OLVG",
#                             "note": "location.user1.org"
#                           },
#                           "custodian": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                             "name": "User A",
#                             "note": null,
#                             "primaryLocation": {
#                               "alt": "0",
#                               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                               "lat": "52.35871773455108",
#                               "long": "4.916762398221842",
#                               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                               "name": "OLVG",
#                               "note": "location.user1.org"
#                             },
#                             "type": "Person"
#                           },
#                           "id": "06E0HEN9QC49441DD7QNWSWKH8",
#                           "metadata": null,
#                           "name": "Filament",
#                           "onhandQuantity": {
#                             "hasNumericalValue": "-49",
#                             "hasUnit": {
#                               "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                               "label": "kg",
#                               "symbol": "om2:kilogram"
#                             }
#                           },
#                           "primaryAccountable": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM",
#                             "name": "User A",
#                             "note": null,
#                             "primaryLocation": {
#                               "alt": "0",
#                               "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                               "lat": "52.35871773455108",
#                               "long": "4.916762398221842",
#                               "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                               "name": "OLVG",
#                               "note": "location.user1.org"
#                             },
#                             "type": "Person"
#                           },
#                           "trackingIdentifier": "Filament-2103",
#                           "type": "EconomicResource"
#                         },
#                         "resourceQuantity": {
#                           "hasNumericalValue": "1",
#                           "hasUnit": {
#                             "id": "06E0HEMG54NJ6C3N54Z9FNA848",
#                             "label": "kg",
#                             "symbol": "om2:kilogram"
#                           }
#                         },
#                         "toLocation": {
#                           "alt": "0",
#                           "id": "06E0HEM4KFN6RQVN7V2BV2AT40",
#                           "lat": "52.35871773455108",
#                           "long": "4.916762398221842",
#                           "mappableAddress": "Oosterpark 9, 1091 AC Amsterdam",
#                           "name": "OLVG",
#                           "note": "location.user1.org"
#                         },
#                         "toResourceInventoriedAs": null,
#                         "triggeredBy": null,
#                         "type": "EconomicEvent",
#                         "name": "raise",
#                         "children": []
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   }
# ]
#
# ✓ Traced 8 resources

# %% [markdown]
# ### Query DPP from Zenflows

# %%
be_dpp = get_dpp(trace_me, endpoint=ENDPOINT)
print(json.dumps(be_dpp, indent=2))
# Out:
# [
#   {
#     "node": {
#       "accountingQuantity": {
#         "hasNumericalValue": "1",
#         "hasUnit": {
#           "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#         }
#       },
#       "classifiedAs": null,
#       "conformsTo": {
#         "id": "06E0HEN30JT66WW95TAZZDYNG0"
#       },
#       "containedIn": {
#         "id": null
#       },
#       "currentLocation": {
#         "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#       },
#       "custodian": {
#         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#       },
#       "id": "06E0HENR5WEJBR71GZGW5V9G04",
#       "license": null,
#       "licensor": null,
#       "lot": {
#         "id": null
#       },
#       "metadata": null,
#       "name": "3D-object-Luffy",
#       "note": null,
#       "okhv": null,
#       "onhandQuantityHas": {
#         "hasUnit": {
#           "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#         },
#         "numericalValue": "1"
#       },
#       "previousEvent": {
#         "id": "06E0HENR5F94R1GQJRGXB8X2ZC"
#       },
#       "primaryAccountable": {
#         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#       },
#       "repo": null,
#       "stage": {
#         "id": null
#       },
#       "state": {
#         "id": null
#       },
#       "trackingIdentifier": "3D-object-Luffy-5595",
#       "unitOfEffort": {
#         "id": null
#       },
#       "version": null
#     },
#     "type": "EconomicResource",
#     "children": [
#       {
#         "node": {
#           "action": {
#             "id": "produce"
#           },
#           "agreedIn": null,
#           "atLocation": {
#             "id": null
#           },
#           "effortQuantity": {
#             "hasNumericalValue": null,
#             "hasUnit": {
#               "id": null
#             }
#           },
#           "hasBeginning": null,
#           "hasEnd": null,
#           "hasPointInTime": "2026-01-29T07:49:39.734309Z",
#           "id": "06E0HENR5F94R1GQJRGXB8X2ZC",
#           "inputOf": {
#             "id": null
#           },
#           "note": "produce 3D-object-Luffy",
#           "outputOf": {
#             "id": "06E0HEMRY7GH2V2TWQX93CQE84"
#           },
#           "previousEvent": {
#             "id": null
#           },
#           "provider": {
#             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#           },
#           "realizationOf": {
#             "id": null
#           },
#           "receiver": {
#             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#           },
#           "resourceClassifiedAs": null,
#           "resourceConformsTo": {
#             "id": "06E0HEN30JT66WW95TAZZDYNG0"
#           },
#           "resourceInventoriedAs": {
#             "id": "06E0HENR5WEJBR71GZGW5V9G04"
#           },
#           "resourceMetadata": null,
#           "resourceQuantity": {
#             "hasNumericalValue": "1",
#             "hasUnit": {
#               "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#             }
#           },
#           "toLocation": {
#             "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#           },
#           "toResourceInventoriedAs": {
#             "id": null
#           },
#           "triggeredBy": {
#             "id": null
#           }
#         },
#         "type": "EconomicEvent",
#         "children": [
#           {
#             "node": {
#               "basedOn": {
#                 "id": null
#               },
#               "classifiedAs": null,
#               "deletable": false,
#               "finished": false,
#               "groupedIn": {
#                 "id": null
#               },
#               "hasBeginning": "2026-01-29T07:49:32.042607Z",
#               "hasEnd": "2026-01-29T07:49:32.042607Z",
#               "id": "06E0HEMRY7GH2V2TWQX93CQE84",
#               "name": "Create_3D_object_Luffy",
#               "note": "3D printing process to create object 'Luffy' performed by User A",
#               "plannedWithin": {
#                 "id": null
#               }
#             },
#             "type": "Process",
#             "children": [
#               {
#                 "node": {
#                   "action": {
#                     "id": "cite"
#                   },
#                   "agreedIn": null,
#                   "atLocation": {
#                     "id": null
#                   },
#                   "effortQuantity": {
#                     "hasNumericalValue": null,
#                     "hasUnit": {
#                       "id": null
#                     }
#                   },
#                   "hasBeginning": null,
#                   "hasEnd": null,
#                   "hasPointInTime": "2026-01-29T07:49:39.117151Z",
#                   "id": "06E0HENMKG1JBBC73YGP9Z9Q7C",
#                   "inputOf": {
#                     "id": "06E0HEMRY7GH2V2TWQX93CQE84"
#                   },
#                   "note": "cite 3D-gcode-file-Luffy",
#                   "outputOf": {
#                     "id": null
#                   },
#                   "previousEvent": {
#                     "id": "06E0HENE3V22AHWYXSMRQP4944"
#                   },
#                   "provider": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                   },
#                   "realizationOf": {
#                     "id": null
#                   },
#                   "receiver": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                   },
#                   "resourceClassifiedAs": null,
#                   "resourceConformsTo": {
#                     "id": null
#                   },
#                   "resourceInventoriedAs": {
#                     "id": "06E0HENE47K7BVKH5XPGZW4QCW"
#                   },
#                   "resourceMetadata": null,
#                   "resourceQuantity": {
#                     "hasNumericalValue": "1",
#                     "hasUnit": {
#                       "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#                     }
#                   },
#                   "toLocation": {
#                     "id": null
#                   },
#                   "toResourceInventoriedAs": {
#                     "id": null
#                   },
#                   "triggeredBy": {
#                     "id": null
#                   }
#                 },
#                 "type": "EconomicEvent",
#                 "children": [
#                   {
#                     "node": {
#                       "accountingQuantity": {
#                         "hasNumericalValue": "1",
#                         "hasUnit": {
#                           "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#                         }
#                       },
#                       "classifiedAs": null,
#                       "conformsTo": {
#                         "id": "06E0HEN4HR98SD89N1PWGPAHJ8"
#                       },
#                       "containedIn": {
#                         "id": null
#                       },
#                       "currentLocation": {
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#                       },
#                       "custodian": {
#                         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                       },
#                       "id": "06E0HENE47K7BVKH5XPGZW4QCW",
#                       "license": null,
#                       "licensor": null,
#                       "lot": {
#                         "id": null
#                       },
#                       "metadata": null,
#                       "name": "3D-gcode-file-Luffy",
#                       "note": null,
#                       "okhv": null,
#                       "onhandQuantityHas": {
#                         "hasUnit": {
#                           "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#                         },
#                         "numericalValue": "1"
#                       },
#                       "previousEvent": {
#                         "id": "06E0HENMKG1JBBC73YGP9Z9Q7C"
#                       },
#                       "primaryAccountable": {
#                         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                       },
#                       "repo": null,
#                       "stage": {
#                         "id": null
#                       },
#                       "state": {
#                         "id": null
#                       },
#                       "trackingIdentifier": "3D-gcode-file-Luffy-4598",
#                       "unitOfEffort": {
#                         "id": null
#                       },
#                       "version": null
#                     },
#                     "type": "EconomicResource",
#                     "children": [
#                       {
#                         "node": {
#                           "action": {
#                             "id": "raise"
#                           },
#                           "agreedIn": null,
#                           "atLocation": {
#                             "id": null
#                           },
#                           "effortQuantity": {
#                             "hasNumericalValue": null,
#                             "hasUnit": {
#                               "id": null
#                             }
#                           },
#                           "hasBeginning": null,
#                           "hasEnd": null,
#                           "hasPointInTime": "2026-01-29T07:49:37.371061Z",
#                           "id": "06E0HENE3V22AHWYXSMRQP4944",
#                           "inputOf": {
#                             "id": null
#                           },
#                           "note": "create resource",
#                           "outputOf": {
#                             "id": null
#                           },
#                           "previousEvent": {
#                             "id": null
#                           },
#                           "provider": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                           },
#                           "realizationOf": {
#                             "id": null
#                           },
#                           "receiver": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                           },
#                           "resourceClassifiedAs": null,
#                           "resourceConformsTo": {
#                             "id": "06E0HEN4HR98SD89N1PWGPAHJ8"
#                           },
#                           "resourceInventoriedAs": {
#                             "id": "06E0HENE47K7BVKH5XPGZW4QCW"
#                           },
#                           "resourceMetadata": null,
#                           "resourceQuantity": {
#                             "hasNumericalValue": "1",
#                             "hasUnit": {
#                               "id": "06E0HEMDRGE0944KEG0W0JNSH8"
#                             }
#                           },
#                           "toLocation": {
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#                           },
#                           "toResourceInventoriedAs": {
#                             "id": null
#                           },
#                           "triggeredBy": {
#                             "id": null
#                           }
#                         },
#                         "type": "EconomicEvent",
#                         "children": []
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "node": {
#                   "action": {
#                     "id": "consume"
#                   },
#                   "agreedIn": null,
#                   "atLocation": {
#                     "id": null
#                   },
#                   "effortQuantity": {
#                     "hasNumericalValue": null,
#                     "hasUnit": {
#                       "id": null
#                     }
#                   },
#                   "hasBeginning": null,
#                   "hasEnd": null,
#                   "hasPointInTime": "2026-01-29T07:49:38.607765Z",
#                   "id": "06E0HENJF7HGWV14D1S37PVASG",
#                   "inputOf": {
#                     "id": "06E0HEMRY7GH2V2TWQX93CQE84"
#                   },
#                   "note": "consume electrical energy for 3D-object-Luffy",
#                   "outputOf": {
#                     "id": null
#                   },
#                   "previousEvent": {
#                     "id": "06E0HENBRC3M2CPY187PHCM7W4"
#                   },
#                   "provider": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                   },
#                   "realizationOf": {
#                     "id": null
#                   },
#                   "receiver": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                   },
#                   "resourceClassifiedAs": null,
#                   "resourceConformsTo": {
#                     "id": null
#                   },
#                   "resourceInventoriedAs": {
#                     "id": "06E0HENBRZWNFPT7GPWY892ZB8"
#                   },
#                   "resourceMetadata": null,
#                   "resourceQuantity": {
#                     "hasNumericalValue": "500",
#                     "hasUnit": {
#                       "id": "06E0HEMPXGECEQSRQDD9M1XHER"
#                     }
#                   },
#                   "toLocation": {
#                     "id": null
#                   },
#                   "toResourceInventoriedAs": {
#                     "id": null
#                   },
#                   "triggeredBy": {
#                     "id": null
#                   }
#                 },
#                 "type": "EconomicEvent",
#                 "children": [
#                   {
#                     "node": {
#                       "accountingQuantity": {
#                         "hasNumericalValue": "500",
#                         "hasUnit": {
#                           "id": "06E0HEMPXGECEQSRQDD9M1XHER"
#                         }
#                       },
#                       "classifiedAs": null,
#                       "conformsTo": {
#                         "id": "06E0HEN0HSAHNR4DWXDQS2KCV0"
#                       },
#                       "containedIn": {
#                         "id": null
#                       },
#                       "currentLocation": {
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#                       },
#                       "custodian": {
#                         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                       },
#                       "id": "06E0HENBRZWNFPT7GPWY892ZB8",
#                       "license": null,
#                       "licensor": null,
#                       "lot": {
#                         "id": null
#                       },
#                       "metadata": null,
#                       "name": "Electrical-Energy",
#                       "note": null,
#                       "okhv": null,
#                       "onhandQuantityHas": {
#                         "hasUnit": {
#                           "id": "06E0HEMPXGECEQSRQDD9M1XHER"
#                         },
#                         "numericalValue": "500"
#                       },
#                       "previousEvent": {
#                         "id": "06E0HENJF7HGWV14D1S37PVASG"
#                       },
#                       "primaryAccountable": {
#                         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                       },
#                       "repo": null,
#                       "stage": {
#                         "id": null
#                       },
#                       "state": {
#                         "id": null
#                       },
#                       "trackingIdentifier": "Electrical-Energy-4467",
#                       "unitOfEffort": {
#                         "id": null
#                       },
#                       "version": null
#                     },
#                     "type": "EconomicResource",
#                     "children": [
#                       {
#                         "node": {
#                           "action": {
#                             "id": "raise"
#                           },
#                           "agreedIn": null,
#                           "atLocation": {
#                             "id": null
#                           },
#                           "effortQuantity": {
#                             "hasNumericalValue": null,
#                             "hasUnit": {
#                               "id": null
#                             }
#                           },
#                           "hasBeginning": null,
#                           "hasEnd": null,
#                           "hasPointInTime": "2026-01-29T07:49:36.854033Z",
#                           "id": "06E0HENBRC3M2CPY187PHCM7W4",
#                           "inputOf": {
#                             "id": null
#                           },
#                           "note": "create resource",
#                           "outputOf": {
#                             "id": null
#                           },
#                           "previousEvent": {
#                             "id": null
#                           },
#                           "provider": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                           },
#                           "realizationOf": {
#                             "id": null
#                           },
#                           "receiver": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                           },
#                           "resourceClassifiedAs": null,
#                           "resourceConformsTo": {
#                             "id": "06E0HEN0HSAHNR4DWXDQS2KCV0"
#                           },
#                           "resourceInventoriedAs": {
#                             "id": "06E0HENBRZWNFPT7GPWY892ZB8"
#                           },
#                           "resourceMetadata": null,
#                           "resourceQuantity": {
#                             "hasNumericalValue": "1000",
#                             "hasUnit": {
#                               "id": "06E0HEMPXGECEQSRQDD9M1XHER"
#                             }
#                           },
#                           "toLocation": {
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#                           },
#                           "toResourceInventoriedAs": {
#                             "id": null
#                           },
#                           "triggeredBy": {
#                             "id": null
#                           }
#                         },
#                         "type": "EconomicEvent",
#                         "children": []
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "node": {
#                   "action": {
#                     "id": "consume"
#                   },
#                   "agreedIn": null,
#                   "atLocation": {
#                     "id": null
#                   },
#                   "effortQuantity": {
#                     "hasNumericalValue": null,
#                     "hasUnit": {
#                       "id": null
#                     }
#                   },
#                   "hasBeginning": null,
#                   "hasEnd": null,
#                   "hasPointInTime": "2026-01-29T07:49:37.989064Z",
#                   "id": "06E0HENG3EYV0ENHPDQZ4BPTG8",
#                   "inputOf": {
#                     "id": "06E0HEMRY7GH2V2TWQX93CQE84"
#                   },
#                   "note": "consume filament for 3D-object-Luffy",
#                   "outputOf": {
#                     "id": null
#                   },
#                   "previousEvent": {
#                     "id": "06E0HEN9Q7XH0YRTNKRC1XBW94"
#                   },
#                   "provider": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                   },
#                   "realizationOf": {
#                     "id": null
#                   },
#                   "receiver": {
#                     "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                   },
#                   "resourceClassifiedAs": null,
#                   "resourceConformsTo": {
#                     "id": null
#                   },
#                   "resourceInventoriedAs": {
#                     "id": "06E0HEN9QC49441DD7QNWSWKH8"
#                   },
#                   "resourceMetadata": null,
#                   "resourceQuantity": {
#                     "hasNumericalValue": "50",
#                     "hasUnit": {
#                       "id": "06E0HEMG54NJ6C3N54Z9FNA848"
#                     }
#                   },
#                   "toLocation": {
#                     "id": null
#                   },
#                   "toResourceInventoriedAs": {
#                     "id": null
#                   },
#                   "triggeredBy": {
#                     "id": null
#                   }
#                 },
#                 "type": "EconomicEvent",
#                 "children": [
#                   {
#                     "node": {
#                       "accountingQuantity": {
#                         "hasNumericalValue": "-49",
#                         "hasUnit": {
#                           "id": "06E0HEMG54NJ6C3N54Z9FNA848"
#                         }
#                       },
#                       "classifiedAs": null,
#                       "conformsTo": {
#                         "id": "06E0HEMXT5EQ3E9A0GE1KY5KNW"
#                       },
#                       "containedIn": {
#                         "id": null
#                       },
#                       "currentLocation": {
#                         "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#                       },
#                       "custodian": {
#                         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                       },
#                       "id": "06E0HEN9QC49441DD7QNWSWKH8",
#                       "license": null,
#                       "licensor": null,
#                       "lot": {
#                         "id": null
#                       },
#                       "metadata": null,
#                       "name": "Filament",
#                       "note": null,
#                       "okhv": null,
#                       "onhandQuantityHas": {
#                         "hasUnit": {
#                           "id": "06E0HEMG54NJ6C3N54Z9FNA848"
#                         },
#                         "numericalValue": "-49"
#                       },
#                       "previousEvent": {
#                         "id": "06E0HENG3EYV0ENHPDQZ4BPTG8"
#                       },
#                       "primaryAccountable": {
#                         "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                       },
#                       "repo": null,
#                       "stage": {
#                         "id": null
#                       },
#                       "state": {
#                         "id": null
#                       },
#                       "trackingIdentifier": "Filament-2103",
#                       "unitOfEffort": {
#                         "id": null
#                       },
#                       "version": null
#                     },
#                     "type": "EconomicResource",
#                     "children": [
#                       {
#                         "node": {
#                           "action": {
#                             "id": "raise"
#                           },
#                           "agreedIn": null,
#                           "atLocation": {
#                             "id": null
#                           },
#                           "effortQuantity": {
#                             "hasNumericalValue": null,
#                             "hasUnit": {
#                               "id": null
#                             }
#                           },
#                           "hasBeginning": null,
#                           "hasEnd": null,
#                           "hasPointInTime": "2026-01-29T07:49:36.136282Z",
#                           "id": "06E0HEN9Q7XH0YRTNKRC1XBW94",
#                           "inputOf": {
#                             "id": null
#                           },
#                           "note": "create resource",
#                           "outputOf": {
#                             "id": null
#                           },
#                           "previousEvent": {
#                             "id": null
#                           },
#                           "provider": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                           },
#                           "realizationOf": {
#                             "id": null
#                           },
#                           "receiver": {
#                             "id": "06DY599GHZ0Y3XH1NTAW2TY4GM"
#                           },
#                           "resourceClassifiedAs": null,
#                           "resourceConformsTo": {
#                             "id": "06E0HEMXT5EQ3E9A0GE1KY5KNW"
#                           },
#                           "resourceInventoriedAs": {
#                             "id": "06E0HEN9QC49441DD7QNWSWKH8"
#                           },
#                           "resourceMetadata": null,
#                           "resourceQuantity": {
#                             "hasNumericalValue": "1",
#                             "hasUnit": {
#                               "id": "06E0HEMG54NJ6C3N54Z9FNA848"
#                             }
#                           },
#                           "toLocation": {
#                             "id": "06E0HEM4KFN6RQVN7V2BV2AT40"
#                           },
#                           "toResourceInventoriedAs": {
#                             "id": null
#                           },
#                           "triggeredBy": {
#                             "id": null
#                           }
#                         },
#                         "type": "EconomicEvent",
#                         "children": []
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   }
# ]

# %% [markdown]
# ### Trace Validation

# %%
trace = trace_query(trace_me, endpoint=ENDPOINT)
check_traces(trace, event_seq, tot_dpp, be_dpp)
# Out:
# ################################################################################
# nr trace: 12, nr events: 0, nr front-end dpp: 12, nr back-end dpp: 12
# ################################################################################
# Check whether there are any duplicated trace items
# ################################################################################
# Check whether there are any duplicated events
# ################################################################################
# Check whether there are any duplicated nodes in front-end dpp
# ################################################################################
# Check whether there are any duplicated nodes in back-end dpp
# ################################################################################
# Are trace items in the events?
# NOT FOUND: trace item 3D-object-Luffy id: 06E0HENR5WEJBR71GZGW5V9G04 of type EconomicResource
# NOT FOUND: trace item produce id: 06E0HENR5F94R1GQJRGXB8X2ZC of type EconomicEvent
# NOT FOUND: trace item Create_3D_object_Luffy id: 06E0HEMRY7GH2V2TWQX93CQE84 of type Process
# NOT FOUND: trace item cite id: 06E0HENMKG1JBBC73YGP9Z9Q7C of type EconomicEvent
# NOT FOUND: trace item raise id: 06E0HENE3V22AHWYXSMRQP4944 of type EconomicEvent
# NOT FOUND: trace item 3D-gcode-file-Luffy id: 06E0HENE47K7BVKH5XPGZW4QCW of type EconomicResource
# NOT FOUND: trace item consume id: 06E0HENJF7HGWV14D1S37PVASG of type EconomicEvent
# NOT FOUND: trace item raise id: 06E0HENBRC3M2CPY187PHCM7W4 of type EconomicEvent
# NOT FOUND: trace item Electrical-Energy id: 06E0HENBRZWNFPT7GPWY892ZB8 of type EconomicResource
# NOT FOUND: trace item consume id: 06E0HENG3EYV0ENHPDQZ4BPTG8 of type EconomicEvent
# NOT FOUND: trace item raise id: 06E0HEN9Q7XH0YRTNKRC1XBW94 of type EconomicEvent
# NOT FOUND: trace item Filament id: 06E0HEN9QC49441DD7QNWSWKH8 of type EconomicResource
# ################################################################################
# Are events in the trace?
# ################################################################################
# Are trace items in the dpp?
# ################################################################################
# Are dpp elements in the trace?
# ################################################################################
# Are back-end and my trace the same?

# %% [markdown]
# ### Save Trace Data

# %%
save_traces(USE_CASE, tot_dpp, trace, be_dpp, event_seq)
print("✓ Trace data saved")
# Out:
# ✓ Trace data saved

# %% [markdown]
# ### Visualize Supply Chain with Sankey Diagram

# %%
labels = []
sources = []
targets = []
values = []
color_nodes = []
color_links = []
assigned = {}
vis_dpp(tot_dpp[0], count=0, assigned=assigned, labels=labels, targets=targets, sources=sources, values=values, color_nodes=color_nodes, color_links=color_links)
sources, targets = consol_trace(assigned, sources, targets)
make_sankey(sources, targets, labels, values, color_nodes, color_links)

# %% [markdown]
# ## Production Complete
#
# The collaborative bike has been successfully produced with a Digital Product Passport!
#
# ### What we accomplished:
#
# 1. ✓ Loaded pre-produced components from setup notebook
# 2. ✓ Created a GC1DPP Digital Product Passport
# 3. ✓ Submitted the DPP to the service and received a ULID
# 4. ✓ Produced the bike with the DPP ULID embedded in metadata
# 5. ✓ Traced the complete supply chain
# 6. ✓ Visualized the material flows
#
# ### Key Integration Point:
#
# The bike's metadata in Zenflows contains:
# ```json
# {
#   "dpp": "01KAX45XX1XSACK6PG3W5FW04Z"
# }
# ```
#
# This ULID links the ValueFlows economic events with the GC1DPP passport, enabling:
# - Complete supply chain traceability
# - Regulatory compliance
# - Circular economy tracking
# - Cryptographic verification
